# %%
import pandas as pd

raw = pd.read_csv("data/unescoPhData.csv")

raw
# Out:
#       Unnamed: 0.1   index  Unnamed: 0 iso_code  \
# 0                0   42830       42831      PHL
# 1                1   42831       42832      PHL
# 2                2   42832       42833      PHL
# 3                3   42833       42834      PHL
# 4                4   42834       42835      PHL
# ...            ...     ...         ...      ...
# 2593          2593  174496      174497      PHL
# 2594          2594  174497      174498      PHL
# 2595          2595  174498      174499      PHL
# 2596          2596  174499      174500      PHL
# 2597          2597  174500      174501      PHL
#
#                         region_group         income_group      country survey  \
# 0     Eastern and South-eastern Asia  Lower middle income  Philippines    DHS
# 1     Eastern and South-eastern Asia  Lower middle income  Philippines    DHS
# 2     Eastern and South-eastern Asia  Lower middle income  Philippines    DHS
# ...
