# %% [markdown]
# # Midterm Activity 1
#
# > An assumption for this activity is that your team was tasked to provide recommendations based on your descriptive and predictive analysis of the assigned dataset.
#
# ### Objectives
#
# 1. Provide a descriptive analysis of a given dataset
# 2. Interpret the results of association rule mining metrics.
# 3. Apply association rule mining as the basis for providing recommendations.

# %%
# Import the dataset
import pandas as pd

themepark = pd.read_csv('themepark.csv')

themepark
# Out:
#               Timestamp Do you agree with the statements above?  \
# 0     4/3/2024 21:30:10                                 I agree
# 1     4/3/2024 21:43:03                                 I agree
# 2     4/3/2024 21:43:20                                 I agree
# 3     4/3/2024 21:43:43                                 I agree
# 4     4/3/2024 21:50:47                                 I agree
# ..                  ...                                     ...
# 108   4/7/2024 20:29:52                                 I agree
# 109   4/7/2024 23:15:33                                 I agree
# 110    4/8/2024 6:29:52                                 I agree
# 111    4/8/2024 8:22:34                                 I agree
# 112  4/10/2024 12:46:33                                 I agree
#
#     What age bracket do you belong to? What is your gender?  \
# 0                                26-40                 Male
# 1                                18-25                 Male
# 2                                18-25               Female
# 3                                18-25                 Male
# 4                                18-25                 Male
# ..                                 ...                  ...
# 108                           Under 18               Female
# 109                        56 and over               Female
# 110                              18-25               Female
# 111                              18-25               Female
# 112                              18-25               Female
#
#     What is the most common reason for you to visit a theme park?  \
# 0                              Vacation, Family Outing
# 1                                        Family Outing
# 2                     Vacation, Special Occasion, Date
# 3                                        Family Outing
# 4                              Vacation, Family Outing
# ..                                                 ...
# 108                                           Vacation
# 109        Vacation, Family Outing, Special Occasion,
# 110                            Vacation, Family Outing
# 111                         Vacation, Special Occasion
# 112    Vacation, Family Outing, Special Occasion, Date
#
#     How often do you visit a theme park?  \
# 0                            Once a year
# 1                            Once a year
# 2                       2-3 times a year
# 3                            Once a year
# 4                            Once a year
# ..                                   ...
# 108                          Once a year
# 109                          Once a year
# 110                     2-3 times a year
# 111                          Once a year
# 112                     2-3 times a year
#
#     Do you have a specific preference for visiting theme parks during certain seasons, or are you open to visiting throughout the year?  \
# 0            I am open to visiting throughout the year
# 1            I prefer visiting during specific seasons
# 2            I am open to visiting throughout the year
# 3            I prefer visiting during specific seasons
# 4            I prefer visiting during specific seasons
# ..                                                 ...
# 108          I am open to visiting throughout the year
# 109          I prefer visiting during specific seasons
# 110          I am open to visiting throughout the year
# 111          I am open to visiting throughout the year
# 112          I am open to visiting throughout the year
#
#     At what time of the week do you typically visit a theme park?  \
# 0                                                 Both
# 1                                                 Both
# 2                                             Weekdays
# 3                                             Weekdays
# 4                                                 Both
# ..                                                 ...
# 108                                           Weekends
# 109                                           Weekends
# 110                                           Weekends
# 111                                           Weekends
# 112                                           Weekends
#
#     During which quarter of the year do you most prefer to visit theme parks?  \
# 0                                                  NaN
# 1                              4th Quarter (Oct - Dec)
# 2                                                  NaN
# 3                              2nd Quarter (Apr - Jun)
# 4                              4th Quarter (Oct - Dec)
# ..                                                 ...
# 108                                                NaN
# 109                            4th Quarter (Oct - Dec)
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
#
#     Do you plan your theme park visits around school holidays and breaks?  \
# 0                                                  NaN
# 1                                                  Yes
# 2                                                  NaN
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 108                                                NaN
# 109                                                Yes
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
#
#      ... How often do you visit each food choice? [Fast Food]  \
# 0    ...                                                1.0
# 1    ...                                                NaN
# 2    ...                                                NaN
# 3    ...                                                3.0
# 4    ...                                                4.0
# ..   ...                                                ...
# 108  ...                                                5.0
# 109  ...                                                NaN
# 110  ...                                                NaN
# 111  ...                                                NaN
# 112  ...                                                5.0
#
#     How often do you visit each food choice? [Restaurants]  \
# 0                                                  1.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  5.0
# 4                                                  5.0
# ..                                                 ...
# 108                                                4.0
# 109                                                4.0
# 110                                                NaN
# 111                                                NaN
# 112                                                5.0
#
#     How often do you visit each food choice? [Food Trucks or Snacks]  \
# 0                                                  4.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  5.0
# 4                                                  4.0
# ..                                                 ...
# 108                                                5.0
# 109                                                4.0
# 110                                                NaN
# 111                                                NaN
# 112                                                5.0
#
#     Aside from Food, what other attractions do you visit in theme parks?  \
# 0    Shopping and Merchandise (Gift Shops, Souvenir...
# 1                                                  NaN
# 2                                                  NaN
# 3                                         None anymore
# 4    Entertainment and Shows (Parades, Fireworks, C...
# ..                                                 ...
# 108  Shopping and Merchandise (Gift Shops, Souvenir...
# 109  Entertainment and Shows (Parades, Fireworks, C...
# 110                                                NaN
# 111                                                NaN
# 112  Shopping and Merchandise (Gift Shops, Souvenir...
#
#      What kinds of merchandise do you usually purchase when visiting a theme park?  \
# 0    Souvenirs (fridge magnets, keychains...), Appa...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                      Gift Shop (plushies, toys...)
# 109  Souvenirs (fridge magnets, keychains...), Appa...
# 110                                                NaN
# 111  Souvenirs (fridge magnets, keychains...), Phot...
# 112  Apparel (hats, shirts...), Gift Shop (plushies...
#
#      How often do you visit each shop? [Souvenirs (fridge magnets, keychains...)]  \
# 0                                                  3.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                3.0
# 110                                                NaN
# 111                                                4.0
# 112                                                3.0
#
#      How often do you visit each shop? [Apparel (hats, shirts...)]  \
# 0                                                  3.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                4.0
# 110                                                NaN
# 111                                                2.0
# 112                                                5.0
#
#      How often do you visit each shop? [Gift Shop (plushies, toys...)]  \
# 0                                                  3.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                5.0
# 109                                                3.0
# 110                                                NaN
# 111                                                3.0
# 112                                                5.0
#
#      How often do you visit each shop? [Photo Services (photo booths, meet-and-greet photos...)]  \
# 0                                                  1.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                3.0
# 110                                                NaN
# 111                                                5.0
# 112                                                5.0
#
#      Aside from Shopping, what other attractions do you visit in theme parks?
# 0                                         None anymore
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108  Entertainment and Shows (Parades, Fireworks, C...
# 109   Food and Dining (Fast Food, Restaurants, Snacks)
# 110                                                NaN
# 111                                       None anymore
# 112                                       None anymore
#
# [113 rows x 38 columns]

# %% [markdown]
# ### Clean Data
#
# Remove Columns 1 and 2 (Timestamp, Do you agree with the statements above?)

# %%
themepark.drop(themepark.columns[0], axis=1)
themepark.drop(themepark.columns[1], axis=1)
themepark
# Out:
#               Timestamp Do you agree with the statements above?  \
# 0     4/3/2024 21:30:10                                 I agree
# 1     4/3/2024 21:43:03                                 I agree
# 2     4/3/2024 21:43:20                                 I agree
# 3     4/3/2024 21:43:43                                 I agree
# 4     4/3/2024 21:50:47                                 I agree
# ..                  ...                                     ...
# 108   4/7/2024 20:29:52                                 I agree
# 109   4/7/2024 23:15:33                                 I agree
# 110    4/8/2024 6:29:52                                 I agree
# 111    4/8/2024 8:22:34                                 I agree
# 112  4/10/2024 12:46:33                                 I agree
#
#     What age bracket do you belong to? What is your gender?  \
# 0                                26-40                 Male
# 1                                18-25                 Male
# 2                                18-25               Female
# 3                                18-25                 Male
# 4                                18-25                 Male
# ..                                 ...                  ...
# 108                           Under 18               Female
# 109                        56 and over               Female
# 110                              18-25               Female
# 111                              18-25               Female
# 112                              18-25               Female
#
#     What is the most common reason for you to visit a theme park?  \
# 0                              Vacation, Family Outing
# 1                                        Family Outing
# 2                     Vacation, Special Occasion, Date
# 3                                        Family Outing
# 4                              Vacation, Family Outing
# ..                                                 ...
# 108                                           Vacation
# 109        Vacation, Family Outing, Special Occasion,
# 110                            Vacation, Family Outing
# 111                         Vacation, Special Occasion
# 112    Vacation, Family Outing, Special Occasion, Date
#
#     How often do you visit a theme park?  \
# 0                            Once a year
# 1                            Once a year
# 2                       2-3 times a year
# 3                            Once a year
# 4                            Once a year
# ..                                   ...
# 108                          Once a year
# 109                          Once a year
# 110                     2-3 times a year
# 111                          Once a year
# 112                     2-3 times a year
#
#     Do you have a specific preference for visiting theme parks during certain seasons, or are you open to visiting throughout the year?  \
# 0            I am open to visiting throughout the year
# 1            I prefer visiting during specific seasons
# 2            I am open to visiting throughout the year
# 3            I prefer visiting during specific seasons
# 4            I prefer visiting during specific seasons
# ..                                                 ...
# 108          I am open to visiting throughout the year
# 109          I prefer visiting during specific seasons
# 110          I am open to visiting throughout the year
# 111          I am open to visiting throughout the year
# 112          I am open to visiting throughout the year
#
#     At what time of the week do you typically visit a theme park?  \
# 0                                                 Both
# 1                                                 Both
# 2                                             Weekdays
# 3                                             Weekdays
# 4                                                 Both
# ..                                                 ...
# 108                                           Weekends
# 109                                           Weekends
# 110                                           Weekends
# 111                                           Weekends
# 112                                           Weekends
#
#     During which quarter of the year do you most prefer to visit theme parks?  \
# 0                                                  NaN
# 1                              4th Quarter (Oct - Dec)
# 2                                                  NaN
# 3                              2nd Quarter (Apr - Jun)
# 4                              4th Quarter (Oct - Dec)
# ..                                                 ...
# 108                                                NaN
# 109                            4th Quarter (Oct - Dec)
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
#
#     Do you plan your theme park visits around school holidays and breaks?  \
# 0                                                  NaN
# 1                                                  Yes
# 2                                                  NaN
# 3                                                   No
# 4                                                  Yes
# ..                                                 ...
# 108                                                NaN
# 109                                                Yes
# 110                                                NaN
# 111                                                NaN
# 112                                                NaN
#
#      ... How often do you visit each food choice? [Fast Food]  \
# 0    ...                                                1.0
# 1    ...                                                NaN
# 2    ...                                                NaN
# 3    ...                                                3.0
# 4    ...                                                4.0
# ..   ...                                                ...
# 108  ...                                                5.0
# 109  ...                                                NaN
# 110  ...                                                NaN
# 111  ...                                                NaN
# 112  ...                                                5.0
#
#     How often do you visit each food choice? [Restaurants]  \
# 0                                                  1.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  5.0
# 4                                                  5.0
# ..                                                 ...
# 108                                                4.0
# 109                                                4.0
# 110                                                NaN
# 111                                                NaN
# 112                                                5.0
#
#     How often do you visit each food choice? [Food Trucks or Snacks]  \
# 0                                                  4.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  5.0
# 4                                                  4.0
# ..                                                 ...
# 108                                                5.0
# 109                                                4.0
# 110                                                NaN
# 111                                                NaN
# 112                                                5.0
#
#     Aside from Food, what other attractions do you visit in theme parks?  \
# 0    Shopping and Merchandise (Gift Shops, Souvenir...
# 1                                                  NaN
# 2                                                  NaN
# 3                                         None anymore
# 4    Entertainment and Shows (Parades, Fireworks, C...
# ..                                                 ...
# 108  Shopping and Merchandise (Gift Shops, Souvenir...
# 109  Entertainment and Shows (Parades, Fireworks, C...
# 110                                                NaN
# 111                                                NaN
# 112  Shopping and Merchandise (Gift Shops, Souvenir...
#
#      What kinds of merchandise do you usually purchase when visiting a theme park?  \
# 0    Souvenirs (fridge magnets, keychains...), Appa...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                      Gift Shop (plushies, toys...)
# 109  Souvenirs (fridge magnets, keychains...), Appa...
# 110                                                NaN
# 111  Souvenirs (fridge magnets, keychains...), Phot...
# 112  Apparel (hats, shirts...), Gift Shop (plushies...
#
#      How often do you visit each shop? [Souvenirs (fridge magnets, keychains...)]  \
# 0                                                  3.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                3.0
# 110                                                NaN
# 111                                                4.0
# 112                                                3.0
#
#      How often do you visit each shop? [Apparel (hats, shirts...)]  \
# 0                                                  3.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                4.0
# 110                                                NaN
# 111                                                2.0
# 112                                                5.0
#
#      How often do you visit each shop? [Gift Shop (plushies, toys...)]  \
# 0                                                  3.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                5.0
# 109                                                3.0
# 110                                                NaN
# 111                                                3.0
# 112                                                5.0
#
#      How often do you visit each shop? [Photo Services (photo booths, meet-and-greet photos...)]  \
# 0                                                  1.0
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                3.0
# 110                                                NaN
# 111                                                5.0
# 112                                                5.0
#
#      Aside from Shopping, what other attractions do you visit in theme parks?
# 0                                         None anymore
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 108  Entertainment and Shows (Parades, Fireworks, C...
# 109   Food and Dining (Fast Food, Restaurants, Snacks)
# 110                                                NaN
# 111                                       None anymore
# 112                                       None anymore
#
# [113 rows x 38 columns]

# %% [markdown]
# ### Clean Data
#
# Fill in missing data for 'What type of...' columns

# %%
rides = themepark[[
    'What kinds of rides do you visit?',
   'How often do you visit each type of ride? [Thrill Rides (High-speed roller coasters, Drop towers...)]',
   'How often do you visit each type of ride? [Family Rides (Carousels, Ferris wheels...)]',
   'How often do you visit each type of ride? [Kiddie Rides (Mini Coasters, Teacup rides...)]',
   'How often do you visit each type of ride? [Water Rides (Water slides, Splash pads...)]',
   'How often do you visit each type of ride? [Interactive Rides (Shooting galleries, Simulators...)]',
   'How often do you visit each type of ride? [Show Rides (Storytelling Rides, Horror Houses...)]'
]]

mask = rides.iloc[:, 1:].isna().all(axis=1)
rides.loc[mask, rides.columns[0]] = "I do not visit rides"

shows = themepark[[
    'What kinds of shows do you visit?',
   'How often do you visit each shows? [Stage shows (Live performances, Theatrical Productions...)]',
   'How often do you visit each shows? [Character Meet-and-Greets (Interact with characters from movies, cartoons and fairy tales)]',
   'How often do you visit each shows? [Parades (Floats, Dancers...)]',
   'How often do you visit each shows? [Nighttime Performances (Fireworks Display...)]'
]]

mask = shows.iloc[:, 1:].isna().all(axis=1)
shows.loc[mask, shows.columns[0]] = "I do not visit shows"

foods = themepark[[
    'What kinds of Food do you prefer when visiting a theme park?',
   'How often do you visit each food choice? [Fast Food]',
   'How often do you visit each food choice? [Restaurants]',
   'How often do you visit each food choice? [Food Trucks or Snacks]'
]]

mask = foods.iloc[:, 1:].isna().all(axis=1)
foods.loc[mask, foods.columns[0]] = "I do not buy food"

merchandise = themepark[[
    'What kinds of merchandise do you usually purchase when visiting a theme park?',
   'How often do you visit each shop? [Souvenirs (fridge magnets, keychains...)]',
   'How often do you visit each shop? [Apparel (hats, shirts...)]',
   'How often do you visit each shop? [Gift Shop (plushies, toys...)]',
   'How often do you visit each shop? [Photo Services (photo booths, meet-and-greet photos...)]'
]]

mask = merchandise.iloc[:, 1:].isna().all(axis=1)
merchandise.loc[mask, merchandise.columns[0]] = "I do not purchase merchandise"

rides
# Out:
#                      What kinds of rides do you visit?  \
# 0    Family Rides (Carousels, Ferris wheels...), Wa...
# 1    Family Rides (Carousels, Ferris wheels...), Wa...
# 2    Thrill Rides (High-speed roller coasters, Drop...
# 3    Thrill Rides (High-speed roller coasters, Drop...
# 4                                 I do not visit rides
# ..                                                 ...
# 108  Family Rides (Carousels, Ferris wheels...), Ki...
# 109  Water Rides (Water slides, Splash pads...), In...
# 110  Thrill Rides (High-speed roller coasters, Drop...
# 111  Thrill Rides (High-speed roller coasters, Drop...
# 112  Thrill Rides (High-speed roller coasters, Drop...
#
#      How often do you visit each type of ride? [Thrill Rides (High-speed roller coasters, Drop towers...)]  \
# 0                                                  1.0
# 1                                                  3.0
# 2                                                  5.0
# 3                                                  5.0
# 4                                                  NaN
# ..                                                 ...
# 108                                                3.0
# 109                                                1.0
# 110                                                5.0
# 111                                                3.0
# 112                                                4.0
#
#      How often do you visit each type of ride? [Family Rides (Carousels, Ferris wheels...)]  \
# 0                                                  3.0
# 1                                                  4.0
# 2                                                  3.0
# 3                                                  5.0
# 4                                                  NaN
# ..                                                 ...
# 108                                                5.0
# 109                                                2.0
# 110                                                3.0
# 111                                                4.0
# 112                                                5.0
#
#      How often do you visit each type of ride? [Kiddie Rides (Mini Coasters, Teacup rides...)]  \
# 0                                                  1.0
# 1                                                  2.0
# 2                                                  2.0
# 3                                                  5.0
# 4                                                  NaN
# ..                                                 ...
# 108                                                4.0
# 109                                                1.0
# 110                                                3.0
# 111                                                2.0
# 112                                                2.0
#
#      How often do you visit each type of ride? [Water Rides (Water slides, Splash pads...)]  \
# 0                                                  4.0
# 1                                                  5.0
# 2                                                  5.0
# 3                                                  5.0
# 4                                                  NaN
# ..                                                 ...
# 108                                                1.0
# 109                                                3.0
# 110                                                5.0
# 111                                                3.0
# 112                                                4.0
#
#      How often do you visit each type of ride? [Interactive Rides (Shooting galleries, Simulators...)]  \
# 0                                                  4.0
# 1                                                  5.0
# 2                                                  4.0
# 3                                                  5.0
# 4                                                  NaN
# ..                                                 ...
# 108                                                4.0
# 109                                                2.0
# 110                                                3.0
# 111                                                4.0
# 112                                                5.0
#
#      How often do you visit each type of ride? [Show Rides (Storytelling Rides, Horror Houses...)]
# 0                                                  4.0
# 1                                                  5.0
# 2                                                  5.0
# 3                                                  5.0
# 4                                                  NaN
# ..                                                 ...
# 108                                                4.0
# 109                                                1.0
# 110                                                2.0
# 111                                                2.0
# 112                                                5.0
#
# [113 rows x 7 columns]

# %% [markdown]
# ### Combine all the types of attractions the visitors go to

# %%
columns_order = [
    'What attractions do you visit in theme parks?',
    'Aside from Entertainment, what other attractions do you visit in theme parks?',
    'Aside from Food, what other attractions do you visit in theme parks?',
    'Aside from Shopping, what other attractions do you visit in theme parks?'
]

def combine_attractions(row):
    included_values = []
    previous_values = []

    for col in columns_order:
        current_val = row[col]

        is_valid = (pd.notna(current_val) and (str(current_val).strip() != "") and (str(current_val) != "None anymore"))

        is_duplicate = current_val in previous_values

        if is_valid and not is_duplicate:
            included_values.append(str(current_val))

        previous_values.append(current_val)

    return ", ".join(included_values)

combined_attractions = themepark.apply(combine_attractions, axis=1)

combined_attractions
# Out:
# 0      Rides (Roller coasters, Ferris wheels...), Foo...
# 1      Entertainment and Shows (Parades, Fireworks, C...
# 2              Rides (Roller coasters, Ferris wheels...)
# 3              Rides (Roller coasters, Ferris wheels...)
# 4      Food and Dining (Fast Food, Restaurants, Snack...
#                              ...
# 108    Rides (Roller coasters, Ferris wheels...), Sho...
# 109    Shopping and Merchandise (Gift Shops, Souvenir...
# 110            Rides (Roller coasters, Ferris wheels...)
# 111            Rides (Roller coasters, Ferris wheels...)
# 112    Entertainment and Shows (Parades, Fireworks, C...
# Length: 113, dtype: object

# %% [markdown]
# ### Import ARM Dependencies. Prepare and Process Attractions

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Split the Attractions
attractions_list = list(combined_attractions.str.split(r',\s*(?![^()]*\))')  # Regex magic to skip commas in (...)
    .apply(
        lambda x: [item.strip() for item in x
                   if item.strip() not in ['', 'None Anymore']]
    ))

# Attractions One-hot Encoding
attractions_apr = TransactionEncoder()
apr_data = attractions_apr.fit(attractions_list).transform(attractions_list)
onehot_apr = pd.DataFrame(apr_data, columns=attractions_apr.columns_)
support_apr = apriori(onehot_apr, min_support = 0.2, use_colnames = True, verbose = 1)

# Get Attractions AR
attractions_ar = association_rules(support_apr, metric = "confidence", min_threshold = 0.6)

# Cleanup Data for Presentation
attractions_ar['antecedents'] = attractions_ar['antecedents'].apply(lambda x: ', '.join(sorted(list(x))))
attractions_ar['consequents'] = attractions_ar['consequents'].apply(lambda x: ', '.join(sorted(list(x))))
attractions_ar = attractions_ar[['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'confidence', 'lift', 'conviction']]

attractions_ar
# Out:
# Processing 6 combinations | Sampling itemset size 32
#                                                                antecedents  \
# 0  Entertainment and Shows (Parades, Fireworks, Character Meet-and-Greets)
# 1                         Food and Dining (Fast Food, Restaurants, Snacks)
# 2        Shopping and Merchandise (Gift Shops, Souvenirs & Photo Services)
#
#                                  consequents  antecedent support  \
# 0  Rides (Roller coasters, Ferris wheels...)            0.407080
# 1  Rides (Roller coasters, Ferris wheels...)            0.318584
# 2  Rides (Roller coasters, Ferris wheels...)            0.477876
#
#    consequent support   support  confidence      lift  conviction
# 0            0.867257  0.283186    0.695652  0.802130    0.436157
# 1            0.867257  0.247788    0.777778  0.896825    0.597345
# 2            0.867257  0.407080    0.851852  0.982237    0.896018

# %% [markdown]
# ### Prepare the specific attractions data

# %%
def process_column(series):
    return (
        series
        .str.split(r',\s*(?![^()]*\))', regex=True)  # Split by commas not in (...)
        .apply(lambda x: [item.strip() for item in x if item.strip()]
                         if isinstance(x, list)  # Process non-NaN entries
                         else [])                # Return empty list for NaN/empty
    )

# Process each column
rides_data = process_column(themepark['What kinds of rides do you visit?']).tolist()
shows_data = process_column(themepark['What kinds of shows do you visit?']).tolist()
merch_data = process_column(themepark['What kinds of merchandise do you usually purchase when visiting a theme park?']).tolist()
food_data = process_column(themepark['What kinds of Food do you prefer when visiting a theme park?']).tolist()

rides_data
# Out:
# [['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)'],
#  [],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  [],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)'],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  [],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)'],
#  [],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  [],
#  ['Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  [],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Family Rides (Carousels, Ferris wheels...)',
#   'Kiddie Rides (Mini Coasters, Teacup rides...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)'],
#  ['Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Water Rides (Water slides, Splash pads...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)'],
#  ['Thrill Rides (High-speed roller coasters, Drop towers...)',
#   'Family Rides (Carousels, Ferris wheels...)',
#   'Water Rides (Water slides, Splash pads...)',
#   'Interactive Rides (Shooting galleries, Simulators...)',
#   'Show Rides (Storytelling Rides, Horror Houses...)']]

# %% [markdown]
# ### Process Specific Attractions Data

# %%
specific_apr = TransactionEncoder()

# Shows APR
shows_apr_data = specific_apr.fit(shows_data).transform(shows_data)
shows_onehot_apr = pd.DataFrame(shows_apr_data, columns=specific_apr.columns_)
shows_support_apr = apriori(shows_onehot_apr, min_support = 0.2, use_colnames = True, verbose = 1)

# Rides APR
rides_apr_data = specific_apr.fit(rides_data).transform(rides_data)
rides_onehot_apr = pd.DataFrame(rides_apr_data, columns=specific_apr.columns_)
rides_support_apr = apriori(rides_onehot_apr, min_support = 0.2, use_colnames = True, verbose = 1)

# Merch APR
merch_apr_data = specific_apr.fit(merch_data).transform(merch_data)
merch_onehot_apr = pd.DataFrame(merch_apr_data, columns=specific_apr.columns_)
merch_support_apr = apriori(merch_onehot_apr, min_support = 0.2, use_colnames = True, verbose = 1)

# Foods APR
food_apr_data = specific_apr.fit(food_data).transform(food_data)
food_onehot_apr = pd.DataFrame(food_apr_data, columns=specific_apr.columns_)
food_support_apr = apriori(food_onehot_apr, min_support = 0.2, use_colnames = True, verbose = 1)

# Get Association Rules Values
shows_ar = association_rules(shows_support_apr, metric = "confidence", min_threshold = 0.6)
rides_ar = association_rules(rides_support_apr, metric = "confidence", min_threshold = 0.6)
merch_ar = association_rules(merch_support_apr, metric = "confidence", min_threshold = 0.6)
food_ar = association_rules(food_support_apr, metric = "confidence", min_threshold = 0.6)

# Cleanup Data for Presentation
shows_ar['antecedents'] = shows_ar['antecedents'].apply(lambda x: ', '.join(sorted(list(x))))
shows_ar['consequents'] = shows_ar['consequents'].apply(lambda x: ', '.join(sorted(list(x))))
rides_ar['antecedents'] = rides_ar['antecedents'].apply(lambda x: ', '.join(sorted(list(x))))
rides_ar['consequents'] = rides_ar['consequents'].apply(lambda x: ', '.join(sorted(list(x))))
merch_ar['antecedents'] = merch_ar['antecedents'].apply(lambda x: ', '.join(sorted(list(x))))
merch_ar['consequents'] = merch_ar['consequents'].apply(lambda x: ', '.join(sorted(list(x))))
food_ar['antecedents'] = food_ar['antecedents'].apply(lambda x: ', '.join(sorted(list(x))))
food_ar['consequents'] = food_ar['consequents'].apply(lambda x: ', '.join(sorted(list(x))))

shows_ar = shows_ar[['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'confidence', 'lift', 'conviction']]
rides_ar = rides_ar[['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'confidence', 'lift', 'conviction']]
merch_ar = merch_ar[['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'confidence', 'lift', 'conviction']]
food_ar = food_ar[['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'confidence', 'lift', 'conviction']]

food_ar
# Out:
# Processing 4 combinations | Sampling itemset size 43
# Processing 6 combinations | Sampling itemset size 65
# Processing 4 combinations | Sampling itemset size 43
# Processing 3 combinations | Sampling itemset size 3
#    antecedents            consequents  antecedent support  consequent support  \
# 0    Fast Food  Food Trucks or Snacks            0.292035            0.495575
# 1    Fast Food            Restaurants            0.292035            0.362832
# 2  Restaurants  Food Trucks or Snacks            0.362832            0.495575
#
#     support  confidence      lift  conviction
# 0  0.238938    0.818182  1.650974    2.774336
# 1  0.212389    0.727273  2.004435    2.336283
# 2  0.247788    0.682927  1.378049    1.590878
